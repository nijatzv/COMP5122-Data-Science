# %% [markdown]
# ### 2. Assessment tasks
# You will analyse the UNDP Peoples’ Climate Vote 2024 dataset, which covers 73 countries and records
# responses by age, education, and country. It includes public attitudes towards climate change, the energy
# transition, and institutional responsibility.
#
#
# You can download the dataset here: https://peoplesclimate.vote/data-center
#
#
# Your tasks for the Coursework Part I are as follows:
# a) Exploratory data analysis (16 marks)
# - Investigate whether there is a consistent age gap across countries in how urgently people want to replace
# coal, oil, and gas with renewable energy.
# - Provide descriptive statistics and visualisations (heatmaps, grouped bar charts).
# - Identify countries with the largest and smallest age gaps.
#
#
# Conclusions (2 marks)
# - Summarise key findings: global age gap
#
# ### 3. General guidance and study support
# - Handle preprocessing carefully (e.g., “All Education” / “All Ages” aggregates).
# - Justify your choice of visualisation and modelling approaches.
# - Clearly explain your evaluation metrics.
#
#
# Links: Module Handbook, Skills@Library, and Minerva resources.

# %%
import pandas as pd
df = pd.read_excel('Peoples_Climate_Vote_Database_2024.xlsx')

# %%
df.columns
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45784 entries, 0 to 45783
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Column1                45784 non-null  int64
#  1   ID                     45784 non-null  int64
#  2   CID                    45784 non-null  int64
#  3   QID                    45784 non-null  int64
#  4   RID                    45784 non-null  int64
#  5   EID                    45784 non-null  int64
#  6   AID                    45784 non-null  int64
#  7   Country                45784 non-null  object
#  8   Question Text          45784 non-null  object
#  9   Question Text (Short)  45784 non-null  object
#  10  Response               45784 non-null  object
#  11  Education              45784 non-null  object
#  12  Age                    45784 non-null  object
#  13  Weighted Mean          25523 non-null  float64
#  14  Cat ID                 45784 non-null  int64
#  15  Category               45784 non-null  object
#  16  Question Context       45784 non-null  object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 5.9+ MB
#              Column1            ID           CID           QID           RID  \
# count   45784.000000  45784.000000  45784.000000  45784.000000  45784.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    29816.380176  29816.380176     37.093286      7.703717    213.274572
# std     17282.044284  17282.044284     21.050790      4.157016    407.183842
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%     15635.750000  15635.750000     19.000000      4.000000      2.000000
# 50%     29637.500000  29637.500000     37.000000      8.000000      3.000000
# 75%     44420.250000  44420.250000     55.000000     11.000000      5.000000
# max     59771.000000  59771.000000     73.000000     15.000000   1000.000000
#
#                  EID           AID Country  \
# count   45784.000000  45784.000000   45784
# unique           NaN           NaN      73
# top              NaN           NaN  Global
# freq             NaN           NaN     639
# mean        2.105452      2.130504     NaN
# std         1.459101      1.454861     NaN
# min         1.000000      1.000000     NaN
# 25%         1.000000      1.000000     NaN
# 50%         1.000000      1.000000     NaN
# 75%         3.000000      3.000000     NaN
# max         5.000000      5.000000     NaN
#
#                                             Question Text  \
# count                                               45784
# unique                                                 15
# top     In your country, who do you think has had the ...
# freq                                                 4508
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#           Question Text (Short)    Response      Education       Age  \
# count                     45784       45784          45784     45784
# unique                       15          45              5         5
# top     Who has had most impact  Don't know  All Education  All Ages
# freq                       4508        9673          25844     25123
# mean                        NaN         NaN            NaN       NaN
# std                         NaN         NaN            NaN       NaN
# min                         NaN         NaN            NaN       NaN
# 25%                         NaN         NaN            NaN       NaN
# 50%                         NaN         NaN            NaN       NaN
# 75%                         NaN         NaN            NaN       NaN
# max                         NaN         NaN            NaN       NaN
#
#         Weighted Mean        Cat ID              Category  \
# count    25523.000000  45784.000000                 45784
# unique            NaN           NaN                     4
# top               NaN           NaN  Peoples' perspective
# freq              NaN           NaN                 14835
# mean        21.118991      2.197056                   NaN
# std         25.002656      1.015639                   NaN
# min          0.000000      1.000000                   NaN
# 25%          3.000000      1.000000                   NaN
# 50%         12.000000      2.000000                   NaN
# 75%         29.000000      3.000000                   NaN
# max         99.000000      4.000000                   NaN
#
#                                          Question Context
# count                                               45784
# unique                                                 15
# top     We asked people who they think has had the mos...
# freq                                                 4508
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
df.head()
# Out:
#    Column1   ID  CID  QID   RID  EID  AID Country  \
# 0       60   60    1   13     1    1    1  Global
# 1       61   61    1   13     2    1    1  Global
# 2       62   62    1   13     3    1    1  Global
# 3       63   63    1   13  1000    1    1  Global
# 4      273  273    1   13     1    1    2  Global
#
#                                        Question Text  \
# 0  Should countries work together on climate chan...
# 1  Should countries work together on climate chan...
# 2  Should countries work together on climate chan...
# 3  Should countries work together on climate chan...
# 4  Should countries work together on climate chan...
#
#         Question Text (Short)  \
# 0  Countries working together
# 1  Countries working together
# 2  Countries working together
# 3  Countries working together
# 4  Countries working together
#
#                                             Response      Education       Age  \
# 0  Yes - they should work together despite their ...  All Education  All Ages
# 1                   No - they should work separately  All Education  All Ages
# 2  It doesn't matter - no country should work on ...  All Education  All Ages
# 3                                         Don't know  All Education  All Ages
# 4  Yes - they should work together despite their ...  All Education  Under 18
#
#    Weighted Mean  Cat ID                         Category  \
# 0           86.0       4  Peoples' call for collaboration
# 1            7.0       4  Peoples' call for collaboration
# 2            5.0       4  Peoples' call for collaboration
# 3            2.0       4  Peoples' call for collaboration
# 4           86.0       4  Peoples' call for collaboration
#
#                                     Question Context
# 0  Climate change is a global problem that requir...
# 1  Climate change is a global problem that requir...
# 2  Climate change is a global problem that requir...
# 3  Climate change is a global problem that requir...
# 4  Climate change is a global problem that requir...

# %%
df_clean = df[(df['Age'] != 'All Ages') & (df['Education'] != 'All Education')]

# %%
df_clean.columns.tolist()
# Out:
# ['Column1',
#  'ID',
#  'CID',
#  'QID',
#  'RID',
#  'EID',
#  'AID',
#  'Country',
#  'Question Text',
#  'Question Text (Short)',
#  'Response',
#  'Education',
#  'Age',
#  'Weighted Mean',
#  'Cat ID',
#  'Category',
#  'Question Context']
